# %% [raw]
# stack為序列的一種，其功能為先近後出
# 舉例來說就像搬家時將物品放進箱子哩，先放進去的東西除非底下有破洞，要取出前必須把上面的東西一一取出，
# 以應用場景來說，網頁前後跳轉功能即可透過stack完成

# %% [markdown]
# # 操作方式

# %% [raw]
# 1.psuh
# 每次新增數值會垂直疊加，記憶體存放方式如下

# %% [markdown]
# ![title](img/push.png)

# %% [raw]
# 2.pop
# 從最上方刪除並取出，如果stack為空物件，將會報錯

# %% [markdown]
# ![title](img/pop.png)

# %% [raw]
# 3.peek
# 檢視stack最外層結果但不刪除

# %% [markdown]
# ![圖片.png](attachment:31440925-19e1-4006-b796-1518607dcf0b.png)

# %% [markdown]
# ![圖片.png](attachment:633020d3-1a2c-4eb1-8a80-6c26449fcf25.png)

# %% [markdown]
# ![圖片.png](attachment:6fca913a-e497-4f88-af07-6b19a30775d2.png)

# %% [markdown]
# ![圖片.png](attachment:c5205add-c024-45ec-bdc9-2457e06aae7b.png)
